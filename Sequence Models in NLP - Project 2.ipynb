# %% [markdown]
# # Stance Detection for the Fake News Challenge
#
# ## Identifying Textual Relationships with Deep Neural Nets
#
# ### Check the problem context [here](https://drive.google.com/open?id=1KfWaZyQdGBw8AUTacJ2yY86Yxgw2Xwq0).
#
# ### Download files required for the project from [here](https://drive.google.com/open?id=10yf39ifEwVihw4xeJJR60oeFBY30Y5J8).

# %% [markdown]
# ## Step1: Load the given dataset
#
# 1. Mount the google drive
#
# 2. Import Glove embeddings
#
# 3. Import the test and train datasets

# %% [markdown]
# ### Mount the google drive to access required project files
#
# Run the below commands

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# #### Path for Project files on google drive
#
# **Note:** You need to change this path according where you have kept the files in google drive.

# %%
project_path = "/content/drive/My Drive/AIML/Sequence Models in NLP - Project 2 /"

# %%
import os
os.chdir(project_path)

# %% [markdown]
# ### Loading the Glove Embeddings

# %%
from zipfile import ZipFile
with ZipFile('glove (1).6B.zip', 'r') as z:
  z.extractall()

# %%
# !ls
# Out:
# glove.6B.100d.txt  glove.6B.zip
# glove.6B.200d.txt  Stance_Detection_for_the_Fake_News_Challenge_Questions.ipynb
# glove.6B.300d.txt  train_bodies.csv
# glove.6B.50d.txt   train_stances.csv

# %% [markdown]
# # Load the dataset [5 Marks]
#
# 1. Using [read_csv()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) in pandas load the given train datasets files **`train_bodies.csv`** and **`train_stances.csv`**
#
# 2. Using [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) command in pandas merge the two datasets based on the Body ID.
#
# Note: Save the final merged dataset in a dataframe with name **`dataset`**.

# %%
import pandas as pd
data1=pd.read_csv('train_bodies.csv')
data2=pd.read_csv('train_stances.csv')

# %%
#pd.merge()

# %%
dataset=data1.merge(data2)

# %% [markdown]
# <h2> Check1:</h2>
#
# <h3> You should see the below output if you run `dataset.head()` command as given below </h3>

# %%
dataset.head()
# Out:
#    Body ID  ...     Stance
# 0        0  ...  unrelated
# 1        0  ...  unrelated
# 2        0  ...  unrelated
# 3        0  ...  unrelated
# 4        0  ...  unrelated
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Step2: Data Pre-processing and setting some hyper parameters needed for model
#
#
# #### Run the code given below to set the required parameters.
#
# 1. `MAX_SENTS` = Maximum no.of sentences to consider in an article.
#
# 2. `MAX_SENT_LENGTH` = Maximum no.of words to consider in a sentence.
#
# 3. `MAX_NB_WORDS` = Maximum no.of words in the total vocabualry.
#
# 4. `MAX_SENTS_HEADING` = Maximum no.of sentences to consider in a heading of an article.

# %%
MAX_NB_WORDS = 20000
MAX_SENTS = 20
MAX_SENTS_HEADING = 1
MAX_SENT_LENGTH = 20
VALIDATION_SPLIT = 0.2
MAX_SEQUENCE_LENGTH=1500

# %% [markdown]
# ### Download the `Punkt` from nltk using the commands given below. This is for sentence tokenization.
#
# For more info on how to use it, read [this](https://stackoverflow.com/questions/35275001/use-of-punktsentencetokenizer-in-nltk).

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Tokenizing the text and loading the pre-trained Glove word embeddings for each token  [5 marks]

# %% [markdown]
# Keras provides [Tokenizer API](https://keras.io/preprocessing/text/) for preparing text. Read it before going any further.

# %% [markdown]
# #### Import the Tokenizer from keras preprocessing text

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %% [markdown]
# #### Initialize the Tokenizer class with maximum vocabulary count as `MAX_NB_WORDS` initialized at the start of step2.

# %%
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~')

# %% [markdown]
# #### Now, using fit_on_texts() from Tokenizer class, lets encode the data
#
# Note: We need to fit articleBody and Headline also to cover all the words.

# %%
texts = dataset['articleBody'].values.tolist() #'text' column contains articlebody
labels = dataset['Headline'].values.tolist() #'label' column contains headline

tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 32393 unique tokens.

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
#labels = to_categorical(labels, num_classes=len(set(labels)))
#labels = to_categorical(labels, num_classes=10)

# %%
texts[0]
# Out:
# 'A small meteorite crashed into a wooded area in Nicaragua\'s capital of Managua overnight, the government said Sunday. Residents reported hearing a mysterious boom that left a 16-foot deep crater near the city\'s airport, the Associated Press reports. \n\nGovernment spokeswoman Rosario Murillo said a committee formed by the government to study the event determined it was a "relatively small" meteorite that "appears to have come off an asteroid that was passing close to Earth." House-sized asteroid 2014 RC, which measured 60 feet in diameter, skimmed the Earth this weekend, ABC News reports. \nMurillo said Nicaragua will ask international experts to help local scientists in understanding what happened.\n\nThe crater left by the meteorite had a radius of 39 feet and a depth of 16 feet,  said Humberto Saballos, a volcanologist with the Nicaraguan Institute of Territorial Studies who was on the committee. He said it is still not clear if the meteorite disintegrated or was buried.\n\nHumberto Garcia, of the Astronomy Center at the National Autonomous University of Nicaragua, said the meteorite could be related to an asteroid that was forecast to pass by the planet Saturday night.\n\n"We have to study it more because it could be ice or rock," he said.\n\nWilfried Strauch, an adviser to the Institute of Territorial Studies, said it was "very strange that no one reported a streak of light. We have to ask if anyone has a photo or something."\n\nLocal residents reported hearing a loud boom Saturday night, but said they didn\'t see anything strange in the sky.\n\n"I was sitting on my porch and I saw nothing, then all of a sudden I heard a large blast. We thought it was a bomb because we felt an expansive wave," Jorge Santamaria told The Associated Press.\n\nThe site of the crater is near Managua\'s international airport and an air force base. Only journalists from state media were allowed to visit it.'

# %% [markdown]
# #### fit_on_texts() gives the following attributes in the output as given [here](https://faroit.github.io/keras-docs/1.2.2/preprocessing/text/).
#
# * **word_counts:** dictionary mapping words (str) to the number of times they appeared on during fit. Only set after fit_on_texts was called.
#
# * **word_docs:** dictionary mapping words (str) to the number of documents/texts they appeared on during fit. Only set after fit_on_texts was called.
#
# * **word_index:** dictionary mapping words (str) to their rank/index (int). Only set after fit_on_texts was called.
#
# * **document_count:** int. Number of documents (texts/sequences) the tokenizer was trained on. Only set after fit_on_texts or fit_on_sequences was called.

# %% [markdown]
# ### Now, tokenize the sentences using nltk sent_tokenize() and encode the senteces with the ids we got form the above `t.word_index`
#
# Initialise 2 lists with names `texts` and `articles`.
#
# ```
# texts = [] to store text of article as it is.
#
# articles = [] split the above text into a list of sentences.
# ```

# %%
from nltk import sent_tokenize
articles = sent_tokenize(''.join(texts))



for x in range(len(texts)):
  articles[x]=sent_tokenize(''.join(texts[x]))

# %%
print(tokenizer.word_index)
# Out:
# {'the': 1, 'to': 2, 'a': 3, 'of': 4, 'in': 5, 'and': 6, 'that': 7, 'is': 8, 'was': 9, 'on': 10, 'for': 11, 'said': 12, 'with': 13, 'he': 14, 'it': 15, 'his': 16, 'have': 17, 'by': 18, 'as': 19, 'has': 20, 'from': 21, 'be': 22, 'at': 23, 'an': 24, 'not': 25, 'are': 26, 'been': 27, 'had': 28, 'who': 29, 'this': 30, 'but': 31, '\n\nthe': 32, 'they': 33, 'were': 34, 'we': 35, 'i': 36, 'after': 37, '”': 38, 'will': 39, 'about': 40, 'or': 41, 'which': 42, 'one': 43, 'up': 44, 'would': 45, 'their': 46, 'state': 47, 'video': 48, 'apple': 49, 'told': 50, 'she': 51, 'her': 52, 'also': 53, '\n\n': 54, 'out': 55, 'when': 56, 'all': 57, 'more': 58, 'no': 59, 'people': 60, 'new': 61, 'isis': 62, 'its': 63, 'you': 64, 'him': 65, 'there': 66, 'news': 67, 'if': 68, 'could': 69, 'man': 70, 'what': 71, 'year': 72, 'time': 73, 'islamic': 74, 'group': 75, 'over': 76, 'some': 77, 'watch': 78, 'al': 79, 'into': 80, 'first': 81, 's': 82, 'being': 83, 'just': 84, 'u': 85, 'syria': 86, 'government': 87, 'last': 88, 'two': 89, 'so': 90, 'them': 91, 'reports': 92, 'reported': 93, 'any': 94, 'police': 95, '—': 96, 'than': 97, 'like': 98, 'before': 99, 'us': 100, 'other': 101, 'media': 102, 'can': 103, 'according': 104, 'then': 105, 'story': 106, 'now': 107, 'while': 108, 'report': 109, 'may': 110, 'north': 111, 'kim': 112, 'where': 113, 'iraq': 114, 'my': 115, 'american': 116, 'made': 117, 'says': 118, 'against': 119, 'because': 120, 'do': 121, 'killed': 122, 'even': 123, 'old': 124, 'only': 125, 'security': 126, 'since': 127, 'officials': 128, 'militants': 129, 'city': 130, 'three': 131, 'our': 132, 'say': 133, 'off': 134, 'years': 135, 'back': 136, 'name': 137, 'how': 138, 'border': 139, 'around': 140, 'during': 141, 'foley': 142, 'get': 143, 'including': 144, 'official': 145, '000': 146, 'still': 147, 'twitter': 148, 'near': 149, 'world': 150, 'family': 151, 'air': 152, 'through': 153, '\n\na': 154, 'week': 155, 'military': 156, 'brown': 157, 'many': 158, 'confirmed': 159, 'under': 160, 'post': 161, 'those': 162, 'found': 163, 'day': 164, 'did': 165, "it's": 166, 'left': 167, 'statement': 168, 'most': 169, '\n\nin': 170, 'claims': 171, 'your': 172, 'death': 173, 'life': 174, 'leader': 175, 'iraqi': 176, 'going': 177, 'very': 178, 'house': 179, 'jong': 180, 'see': 181, 'another': 182, 'released': 183, 'went': 184, 'down': 185, 'fighters': 186, 'haram': 187, 'forces': 188, 'know': 189, 'british': 190, 'tuesday': 191, 'me': 192, 'girls': 193, 'reportedly': 194, 'service': 195, 'month': 196, 'known': 197, 'it’s': 198, 'make': 199, 'way': 200, 'ebola': 201, 'release': 202, 'well': 203, 'these': 204, 'obama': 205, 'public': 206, 'days': 207, 'taken': 208, 'woman': 209, 'times': 210, 'boko': 211, 'journalist': 212, 'least': 213, 'president': 214, 'seen': 215, 'kurdish': 216, '–': 217, 'source': 218, 'part': 219, 'monday': 220, 'syrian': 221, 'believed': 222, 'next': 223, 'shot': 224, 'town': 225, 'company': 226, 'took': 227, 'press': 228, 'later': 229, 'shooting': 230, 'health': 231, 'information': 232, 'attack': 233, 'posted': 234, 'saying': 235, 'heard': 236, 'war': 237, 'claimed': 238, 'hospital': 239, 'used': 240, 'several': 241, '10': 242, 'such': 243, 'intelligence': 244, 'missing': 245, 'mr': 246, 'site': 247, 'korean': 248, 'six': 249, '\n\nhe': 250, 'york': 251, 'long': 252, 'never': 253, 'something': 254, 'son': 255, 'shots': 256, 'show': 257, 'think': 258, 'photo': 259, 'high': 260, 'however': 261, 'come': 262, 'john': 263, 'much': 264, 'home': 265, 'night': 266, 'called': 267, 'wednesday': 268, 'added': 269, 'captured': 270, 'michael': 271, 'same': 272, 'number': 273, 'ago': 274, 'sources': 275, 'country': 276, 'between': 277, 'take': 278, 'held': 279, 'local': 280, 'officer': 281, 'though': 282, 'inside': 283, 'facebook': 284, 'million': 285, '12': 286, 'right': 287, 'go': 288, 'both': 289, 'online': 290, 'un': 291, '2': 292, 'work': 293, 'office': 294, 'former': 295, 'social': 296, 'based': 297, '2014': 298, 'white': 299, 'head': 300, 'control': ...

# %% [markdown]
# ## Check 2:
#
# first element of texts and articles should be as given below.

# %%
texts[0]
# Out:
# 'A small meteorite crashed into a wooded area in Nicaragua\'s capital of Managua overnight, the government said Sunday. Residents reported hearing a mysterious boom that left a 16-foot deep crater near the city\'s airport, the Associated Press reports. \n\nGovernment spokeswoman Rosario Murillo said a committee formed by the government to study the event determined it was a "relatively small" meteorite that "appears to have come off an asteroid that was passing close to Earth." House-sized asteroid 2014 RC, which measured 60 feet in diameter, skimmed the Earth this weekend, ABC News reports. \nMurillo said Nicaragua will ask international experts to help local scientists in understanding what happened.\n\nThe crater left by the meteorite had a radius of 39 feet and a depth of 16 feet,  said Humberto Saballos, a volcanologist with the Nicaraguan Institute of Territorial Studies who was on the committee. He said it is still not clear if the meteorite disintegrated or was buried.\n\nHumberto Garcia, of the Astronomy Center at the National Autonomous University of Nicaragua, said the meteorite could be related to an asteroid that was forecast to pass by the planet Saturday night.\n\n"We have to study it more because it could be ice or rock," he said.\n\nWilfried Strauch, an adviser to the Institute of Territorial Studies, said it was "very strange that no one reported a streak of light. We have to ask if anyone has a photo or something."\n\nLocal residents reported hearing a loud boom Saturday night, but said they didn\'t see anything strange in the sky.\n\n"I was sitting on my porch and I saw nothing, then all of a sudden I heard a large blast. We thought it was a bomb because we felt an expansive wave," Jorge Santamaria told The Associated Press.\n\nThe site of the crater is near Managua\'s international airport and an air force base. Only journalists from state media were allowed to visit it.'

# %%
articles[0]
# Out:
# ["A small meteorite crashed into a wooded area in Nicaragua's capital of Managua overnight, the government said Sunday.",
#  "Residents reported hearing a mysterious boom that left a 16-foot deep crater near the city's airport, the Associated Press reports.",
#  'Government spokeswoman Rosario Murillo said a committee formed by the government to study the event determined it was a "relatively small" meteorite that "appears to have come off an asteroid that was passing close to Earth."',
#  'House-sized asteroid 2014 RC, which measured 60 feet in diameter, skimmed the Earth this weekend, ABC News reports.',
#  'Murillo said Nicaragua will ask international experts to help local scientists in understanding what happened.',
#  'The crater left by the meteorite had a radius of 39 feet and a depth of 16 feet,  said Humberto Saballos, a volcanologist with the Nicaraguan Institute of Territorial Studies who was on the committee.',
#  'He said it is still not clear if the meteorite disintegrated or was buried.',
#  'Humberto Garcia, of the Astronomy Center at the National Autonomous University of Nicaragua, said the meteorite could be related to an asteroid that was forecast to pass by the planet Saturday night.',
#  '"We have to study it more because it could be ice or rock," he said.',
#  'Wilfried Strauch, an adviser to the Institute of Territorial Studies, said it was "very strange that no one reported a streak of light.',
#  'We have to ask if anyone has a photo or something."',
#  "Local residents reported hearing a loud boom Saturday night, but said they didn't see anything strange in the sky.",
#  '"I was sitting on my porch and I saw nothing, then all of a sudden I heard a large blast.',
#  'We thought it was a bomb because we felt an expansive wave," Jorge Santamaria told The Associated Press.',
#  "The site of the crater is near Managua's international airport and an air force base.",
#  'Only journalists from state media were allowed to visit it.']

# %% [markdown]
# # Now iterate through each article and each sentence to encode the words into ids using t.word_index  [5 marks]
#
# Here, to get words from sentence you can use `text_to_word_sequence` from keras preprocessing text.
#
# 1. Import text_to_word_sequence
#
# 2. Initialize a variable of shape (no.of articles, MAX_SENTS, MAX_SENT_LENGTH) with name `data` with zeros first (you can use numpy [np.zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) to initialize with all zeros)and then update it while iterating through the words and sentences in each article.

# %%
import random
import pandas as pd
import numpy as np
def load_kagglefakenews():
    #load training data and put into arrays
    
    data1=pd.read_csv('train_bodies.csv')
    data2=pd.read_csv('train_stances.csv')
    dataset=data1.merge(data2)
    
    texts = dataset['articleBody'].values.tolist() #'text' column contains articlebody
    labels = dataset['Headline'].values.tolist() #'label' column contains headline
    
    
    
    train_data = dataset['articleBody'].values.tolist() #'text' column contains articles
    train_labels = dataset['Stance'].values.tolist() #'label' column contains labels

    #Randomly shuffle data and labels together
    combo = list(zip(train_data, train_labels))
    random.shuffle(combo)
    train_data, train_labels = zip(*combo)
    del dataset #clear up memory

    return np.asarray(train_data).tolist(), np.asarray(train_labels).tolist()

# %%
train_data, train_labels = load_kagglefakenews()

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding
from keras.utils import to_categorical
import pickle

MAX_NB_WORDS=50000 #dictionary size
MAX_SEQUENCE_LENGTH=1500 #max word length of each individual article
EMBEDDING_DIM=300 #dimensionality of the embedding vector (50, 100, 200, 300)
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~')

# %%
from sklearn.preprocessing import LabelBinarizer
def tokenize_trainingdata(texts, labels):
    tokenizer.fit_on_texts(texts)
    #pickle.dump(tokenizer, open('Models/tokenizer.p', 'wb'))
    sequences = tokenizer.texts_to_sequences(texts)
    word_index = tokenizer.word_index
    print('Found %s unique tokens.' % len(word_index))
    data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
    #labels = to_categorical(labels,num_classes=4)
    
    encoder = LabelBinarizer()
    transfomed_label = encoder.fit_transform(labels)
    #king=to_categorical(labels,num_classes=4)
    return data, transfomed_label, word_index

# %%
X, Y, word_index = tokenize_trainingdata(train_data, train_labels)
# Out:
# Found 32393 unique tokens.

# %% [markdown]
# ### Check 3:
#
# Accessing first element in data should give something like given below.

# %% [markdown]
# # Repeat the same process for the `Headings` as well. Use variables with names `texts_heading` and `articles_heading` accordingly. [5 marks]

# %% [markdown]
# ### Now the features are ready, lets make the labels ready for the model to process.
#
# ### Convert labels into one-hot vectors
#
# You can use [get_dummies](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html) in pandas to create one-hot vectors.

# %% [markdown]
# ### Check 4:
#
# The shape of data and labels shoould match the given below numbers.

# %% [markdown]
# ### Shuffle the data

# %% [markdown]
# ### Split into train and validation sets. Split the train set 80:20 ratio to get the train and validation sets.
#
#
# Use the variable names as given below:
#
# x_train, x_val - for body of articles.
#
# x-heading_train, x_heading_val - for heading of articles.
#
# y_train - for training labels.
#
# y_val - for validation labels.

# %%
#split the data (90% train, 5% test, 5% validation)
train_data = X[:int(len(X)*0.9)]
train_labels = Y[:int(len(X)*0.9)]
test_data = X[int(len(X)*0.9):int(len(X)*0.95)]
test_labels = Y[int(len(X)*0.9):int(len(X)*0.95)]
valid_data = X[int(len(X)*0.95):]
valid_labels = Y[int(len(X)*0.95):]

# %% [markdown]
# ### Check 5:
#
# The shape of x_train, x_val, y_train and y_val should match the below numbers.

# %%
print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (44974, 1500)
# (44974, 4)
# (2499, 1500)
# (2499, 4)

# %% [markdown]
# ### Create embedding matrix with the glove embeddings
#
#
# Run the below code to create embedding_matrix which has all the words and their glove embedding if present in glove word list.

# %%
def load_embeddings(word_index, embeddingsfile='glove.6B.%id.txt' %EMBEDDING_DIM):
    embeddings_index = {}
    f = open(embeddingsfile, 'r', encoding='utf8')
    for line in f:
        #here we parse the data from the file
        values = line.split(' ') #split the line by spaces
        word = values[0] #each line starts with the word
        coefs = np.asarray(values[1:], dtype='float32') #the rest of the line is the vector
        embeddings_index[word] = coefs #put into embedding dictionary
    f.close()

    print('Found %s word vectors.' % len(embeddings_index))

    embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
    
    embedding_layer = Embedding(len(word_index) + 1,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    return embedding_layer

# %%
#and build the embedding layer
embedding_layer = load_embeddings(word_index)
# Out:
# Found 400000 word vectors.

# %% [markdown]
# # Try the sequential model approach and report the accuracy score. [10 marks]

# %% [markdown]
# ### Import layers from Keras to build the model

# %%
from keras import Sequential, Model, Input
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D, Flatten, Dense, GlobalAveragePooling1D, Dropout

from keras.layers import LSTM, CuDNNLSTM, RNN, SimpleRNN, Conv2D, GlobalMaxPooling1D
from keras import callbacks

def baseline_model(sequence_input, embedded_sequences, classes=4):
    x = Conv1D(64, 5, activation='relu')(embedded_sequences)
    x = MaxPooling1D(5)(x)
    x = Conv1D(128, 3, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    x = Conv1D(256, 2, activation='relu')(x)
    x = GlobalAveragePooling1D()(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    preds = Dense(classes, activation='softmax')(x)

    model = Model(sequence_input, preds)
    return model

# %% [markdown]
# ### Model

# %% [markdown]
# ### Compile and fit the model

# %%
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

model = baseline_model(sequence_input, embedded_sequences, classes=4)

model.compile(loss='categorical_crossentropy',
              optimizer='adamax',
              metrics=['acc'])

print(model.summary())

model.fit(train_data, train_labels,
          validation_data=(valid_data, valid_labels),
          epochs=25, batch_size=64)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 1500)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 1500, 300)         9718200
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1496, 64)          96064
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 299, 64)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 297, 128)          24704
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 59, 128)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 58, 256)           65792
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2048)              526336
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 11,482,236
# Trainable params: 1,764,036
# Non-trainable params: 9,718,200
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 44974 samples, validate on 2499 samples
# Epoch 1/25
# 44974/44974 [==============================] - 20s 438us/step - loss: 0.7357 - acc: 0.7350 - val_loss: 0.6500 - val_acc: 0.7475
# Epoch 2/25
# 44974/44974 [==============================] - 16s 353us/step - loss: 0.6067 - acc: 0.7749 - val_loss: 0.5845 - val_acc: 0.7851
# Epoch 3/25
# 44974/44974 [==============================] - 16s 359us/step - loss: 0.5579 - acc: 0.7967 - val_loss: 0.5752 - val_acc: 0.7911
# Epoch 4/25
# 44974/44974 [==============================] - 16s 364us/step - loss: 0.5305 - acc: 0.8055 - val_loss: 0.5568 - val_acc: 0.7935
# Epoch 5/25
# 44974/44974 [==============================] - 16s 366us/step - loss: 0.5161 - acc: 0.8105 - val_loss: 0.5275 - val_acc: 0.8023
# Epoch 6/25
# 44974/44974 [==============================] - 16s 364us/step - loss: 0.5053 - acc: 0.8127 - val_loss: 0.5172 - val_acc: 0.8059
# Epoch 7/25
# 44974/44974 [==============================] - 16s 361us/step - loss: 0.4982 - acc: 0.8139 - val_loss: 0.5217 - val_acc: 0.8067
# Epoch 8/25
# 44974/44974 [==============================] - 16s 351us/step - loss: 0.4904 - acc: 0.8153 - val_loss: 0.5292 - val_acc: 0.8075
# Epoch 9/25
# 44974/44974 [==============================] - 16s 350us/step - loss: 0.4825 - acc: 0.8169 - val_loss: 0.5228 - val_acc: 0.8027
# Epoch 10/25
# 44974/44974 [==============================] - 16s 351us/step - loss: 0.4800 - acc: 0.8182 - val_loss: 0.5103 - val_acc: 0.8083
# Epoch 11/25
# 44974/44974 [==============================] - 16s 353us/step - loss: 0.4759 - acc: 0.8187 - val_loss: 0.5080 - val_acc: 0.8103
# Epoch 12/25
# 44974/44974 [==============================] - 16s 363us/step - loss: 0.4754 - acc: 0.8187 - val_loss: 0.5048 - val_acc: 0.8083
# Epoch 13/25
# 44974/44974 [==============================] - 16s 365us/step - loss: 0.4719 - acc: 0.8191 - val_loss: 0.5113 - val_acc: 0.8087
# Epoch 14/25
# 44974/44974 [==============================] - 16s 363us/step - loss: 0.4700 - acc: 0.8181 - val_loss: 0.5026 - val_acc: 0.8091
# Epoch 15/25
# 44974/44974 [==============================] - 16s 362us/step - loss: 0.4681 - acc: 0.8198 - val_loss: 0.5024 - val_acc: 0.8087
# Epoch 16/25
# 44974/44974 [==============================] - 16s 362us/step - loss: 0.4649 - acc: 0.8198 - val_loss: 0.5118 - val_acc: 0.8003
# Epoch 17/25
# 44974/44974 [==============================] - 16s 363us/step - loss: 0.4641 - acc: 0.8198 - val_loss: 0.5053 - val_acc: 0.8083
# Epoch 18/25
# 44974/44974 [==============================] - 16s 361us/step - loss: 0.4633 - acc: 0.8204 - val_loss: 0.5094 - val_acc: 0.8075
# Epoch 19/25
# 44974/44974 [==============================] - 16s 362us/step - loss: 0.4613 - acc: 0.8218 - val_loss: 0.5099 - val_acc: 0.8103
# Epoch 20/25
# 44974/44974 [==============================] - 16s 362us/step - loss: 0.4611 - acc: 0.8204 - val_loss: 0.5079 - val_acc: 0.8075
# Epoch 21/25
# 44974/44974 [==============================] - 16s 357us/step - loss: 0.4600 - acc: 0.8210 - val_loss: 0.5034 - val_acc: 0.8087
# Epoch 22/25
# 44974/44974 [==============================] - 16s 351us/step - loss: 0.4587 - acc: 0.8223 - val_loss: 0.5159 - val_acc: 0.8103
# Epoch 23/25
# 44974/44974 [==============================] - 16s 351us/step - loss: 0.4566 - acc: 0.8219 - val_loss: 0.5253 - val_acc: 0.8063
# Epoch 24/25
# 44974/44974 [==============================] - 16s 361us/step - loss: 0.4577 - acc: 0.8225 - val_loss: 0.4972 - val_acc: 0.8119
# Epoch 25/25
# 44974/44974 [==============================] - 16s 362us/step - loss: 0.4565 - acc: 0.8223 - val_loss: 0.5021 - val_acc: 0.8071

# %%
model.evaluate(test_data, test_labels)
# Out:
# 2499/2499 [==============================] - 1s 214us/step
# [0.5183423686475933, 0.808323329355584]

# %% [markdown]
# ## Build the same model with attention layers included for better performance (Optional)

# %% [markdown]
# ## Fit the model and report the accuracy score for the model with attention layer (Optional)
